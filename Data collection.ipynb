# %% [markdown]
# <h1 style="font-size: xxx-large">SMDA PROJECT:
# DATA COLLECTION AND PREPROCESSING</h1>

# %% [markdown]
# <h1 style="font-size:-large">Loading Packages</h1>

# %%
import requests
import pandas as pd
from datetime import datetime
import calendar
from matplotlib import pyplot as plt
from datetime import timedelta
import ast

# %% [markdown]
# <h1 style="font-size:-large">Retrieving List of Wikipedia Articles</h1>

# %%
API_URL = "https://en.wikipedia.org/w/api.php"

HEADERS = {
    "User-Agent": "AviationResearchBot/1.0 (-)"
}


def get_category_members(category, cmtype="page", limit=500):
    """
    Get members of a Wikipedia category.
    cmtype = "page" (articles), "subcat" (subcategories), or "file"
    """
    members = []
    cmcontinue = None

    while True:
        params = {
            "action": "query",
            "list": "categorymembers",
            "cmtitle": f"Category:{category}",
            "cmlimit": limit,
            "cmtype": cmtype,
            "format": "json"
        }
        if cmcontinue:
            params["cmcontinue"] = cmcontinue

        r = requests.get(API_URL, params=params, headers=HEADERS)

        if r.status_code != 200:
            print(f"HTTP error {r.status_code} for category {category}")
            break
        try:
            data = r.json()
        except Exception:
            print("JSON decode error. Raw response:")
            print(r.text[:500])
            break

        members.extend(data["query"]["categorymembers"])

        if "continue" in data:
            cmcontinue = data["continue"]["cmcontinue"]
            time.sleep(0.1) 
        else:
            break

    return members


def get_all_articles_from_category(category, depth=1, max_depth=2):
    """
    Recursively get all articles from a category, up to max_depth levels.
    depth=1 means root category.
    """
    print(f"{'  ' * (depth-1)}Fetching {category} (depth {depth})")

    articles = []
    articles.extend(get_category_members(category, cmtype="page"))

    if depth >= max_depth:
        return articles

    subcats = get_category_members(category, cmtype="subcat")

    for subcat in subcats:
        subcat_title = subcat["title"].replace("Category:", "")
        articles.extend(get_all_articles_from_category(subcat_title, depth+1, max_depth))

    return articles


articles_country = get_all_articles_from_category("Genocide remembrance days ", max_depth=0)
print(f"Found {len(articles_country)} articles")

all_articles = {a["pageid"]: a["title"] for a in (articles_country)}
print(f"Total unique articles collected: {len(all_articles)}")

df_articles = pd.DataFrame(list(all_articles.items()), columns=["pageid", "title"])
#df_articles.to_csv("Full_list_rememberance_days.csv", index=False)
# Out:
# Fetching Genocide remembrance days  (depth 1)
# Found 11 articles
# Total unique articles collected: 11

# %% [markdown]
# <h1 style="font-size:-large">Retrieving Hyperlinks of Wikipedia Articles</h1>

# %%
def get_wikipedia_links(pageid):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "prop": "links",
        "pageids": pageid,
        "format": "json",
        "pllimit": "max"
    }
    headers = {
        "User-Agent": "MyWikipediaScraper/1.0 (-)"
    }

    links = []
    while True:
        response = requests.get(url, params=params, headers=headers)

        if response.status_code != 200:
            print(f"Error {response.status_code} for pageid {pageid}")
            return []

        try:
            data = response.json()
        except Exception as e:
            print(f"Could not decode JSON for pageid {pageid}: {e}")
            print("Response text:", response.text[:500])  
            return []

        pages = data.get("query", {}).get("pages", {})
        if str(pageid) in pages:
            page = pages[str(pageid)]
            if "links" in page:
                for link in page["links"]:
                    links.append(link["title"])

        if "continue" in data:
            params.update(data["continue"])
        else:
            break

    return links

df_articles["links"] = df_articles["pageid"].apply(get_wikipedia_links)

print(df_articles.head())
# Out:
#      pageid                                  title  \
# 0   4575104      Armenian Genocide Remembrance Day
# 1  25966474                       Black Ribbon Day
# 2  17539056             Circassian Day of Mourning
# 3  53453368  Genocide Remembrance Day (Bangladesh)
# 4  69380022                 Holodomor Memorial Day
#
#                                                links
# 0  [100th anniversary of the Armenian Genocide, 1...
# 1  [2020 Belarusian protests, 2022 Russian invasi...
# 2  [Abzakhs, Ademey, Adygea, Adyghe Xabze, Adyghe...
# 3  [1958 Pakistani coup d'état, 1969 Mass uprisin...
# 4  [Bridget A. Brink, Canada, Causes of the Holod...

# %%
articles = [title.replace(" ", "_") for title in all_articles.values()]

# %%
articles
# Out:
# ['Armenian_Genocide_Remembrance_Day',
#  'Black_Ribbon_Day',
#  'Circassian_Day_of_Mourning',
#  'Genocide_Remembrance_Day_(Bangladesh)',
#  'Holodomor_Memorial_Day',
#  'International_Day_of_Reflection_on_the_1994_Rwanda_Genocide',
#  'Martyred_Intellectuals_Day',
#  'National_Day_for_Truth_and_Reconciliation',
#  'National_Day_of_Remembrance_(Cambodia)',
#  'National_Sorry_Day',
#  'White_Armband_Day']

# %% [markdown]
# <h1 style="font-size:-large">Retrieving daily Pageviews of Wikipedia Articles</h1>

# %%
def get_pageviews(article, start, end):
    """
    Get daily Wikipedia pageviews for one article between start and end dates.
    start, end format: YYYYMMDD
    """
    url = (
        f"https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
        f"en.wikipedia/all-access/all-agents/{article}/daily/{start}/{end}"
    )
    headers = {"User-Agent": "MyResearchBot/1.0 (your_email@example.com)"}

    r = requests.get(url, headers=headers)
    if r.status_code != 200:
        print(f"Error {r.status_code}: Could not fetch {article}")
        return pd.DataFrame()

    data = r.json()
    if "items" not in data:
        return pd.DataFrame()

    views = [
        {"date": item["timestamp"][:8], "views": item["views"]}
        for item in data["items"]
    ]

    df = pd.DataFrame(views)
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")
    df["article"] = article
    return df

# %%
# Define  start and end dates
start_date = "20160101"
end_date = "20250101"

# Apply the function to all articles and concatenate the results
page_views = pd.concat([get_pageviews(article, start_date, end_date) for article in articles], ignore_index=True)

# Display the combined DataFrame
print(page_views)
# Out:
# Error 404: Could not fetch Day_of_Salvation_and_Liberation
#             date  views         article
# 0     2016-01-01    205  Liberation_Day
# 1     2016-01-02    111  Liberation_Day
# 2     2016-01-03     82  Liberation_Day
# 3     2016-01-04    115  Liberation_Day
# 4     2016-01-05    130  Liberation_Day
# ...          ...    ...             ...
# 87907 2024-12-28     10    Waterloo_Day
# 87908 2024-12-29      7    Waterloo_Day
# 87909 2024-12-30      9    Waterloo_Day
# 87910 2024-12-31      8    Waterloo_Day
# 87911 2025-01-01      2    Waterloo_Day
#
# [87912 rows x 3 columns]

# %%
page_views
# Out:
#             date  views         article
# 0     2016-01-01    205  Liberation_Day
# 1     2016-01-02    111  Liberation_Day
# 2     2016-01-03     82  Liberation_Day
# 3     2016-01-04    115  Liberation_Day
# 4     2016-01-05    130  Liberation_Day
# ...          ...    ...             ...
# 87907 2024-12-28     10    Waterloo_Day
# 87908 2024-12-29      7    Waterloo_Day
# 87909 2024-12-30      9    Waterloo_Day
# 87910 2024-12-31      8    Waterloo_Day
# 87911 2025-01-01      2    Waterloo_Day
#
# [87912 rows x 3 columns]

# %%
page_views["date"] = pd.to_datetime(page_views["date"])

start_date = pd.to_datetime("2015-01-01")
end_date   = pd.to_datetime("2025-01-01")
full_range = pd.date_range(start=start_date, end=end_date, freq="D")

# Count number of days per article
coverage = (
    page_views.groupby("article")["date"]
    .nunique()
    .reset_index(name="n_days")
)

# %%
coverage
# Out:
#                                               article  n_days
# 0                           Armed_Forces_Day_(Poland)    3289
# 1   Day_of_Victory_in_the_Great_Fatherland_Liberat...    3289
# 2                         Independence_Day_(Abkhazia)    2534
# 3                                  Kargil_Vijay_Diwas    3289
# 4                                      Liberation_Day    3289
# ..                                                ...     ...
# 25                              Victory_in_Europe_Day    3289
# 26                     Victory_in_Europe_Day_(Israel)    2456
# 27                             Victory_over_Japan_Day    3289
# 28                                          Võidupüha    3204
# 29                                       Waterloo_Day    3283
#
# [30 rows x 2 columns]

# %%
coverage["n_days"].unique()
# Out:
# array([3289, 2534, 3287, 1380, 1679, 2469, 3276, 3139, 1700, 1490, 3285,
#        2265, 3132, 2456, 3204, 3283])

# %%
expected_days
# Out:
# 3654

# %% [markdown]
# <h1 style="font-size:-large">Retrieving Metadata of Wikipedia Articles</h1>

# %%
API_URL = "https://en.wikipedia.org/w/api.php"
WIKIDATA_API = "https://www.wikidata.org/w/api.php"
HEADERS = {"User-Agent": "RemembranceMetadataFetcher/1.0"}

# Helper: Wikidata label fetch
def get_label_from_wikidata(qid, language="en"):
    params = {
        "action": "wbgetentities",
        "ids": qid,
        "format": "json",
        "languages": language
    }
    r = requests.get(WIKIDATA_API, params=params, headers=HEADERS)
    data = r.json()
    try:
        return data["entities"][qid]["labels"][language]["value"]
    except:
        return None

def get_claims(qid):
    params = {"action": "wbgetclaims", "entity": qid, "format": "json"}
    r = requests.get(WIKIDATA_API, params=params, headers=HEADERS)
    return r.json().get("claims", {})

# Article categories + subcategories
def get_article_categories(title):
    params = {
        "action": "query",
        "titles": title,
        "prop": "categories",
        "cllimit": "max",
        "format": "json"
    }
    r = requests.get(API_URL, params=params, headers=HEADERS)
    data = r.json()
    pages = data.get("query", {}).get("pages", {})
    categories = []
    for _, page in pages.items():
        cats = page.get("categories", [])
        categories = [c["title"] for c in cats]
    return categories

def get_subcategories(category_title, depth=1):
    subcats = []
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": category_title,
        "cmtype": "subcat",
        "cmlimit": "max",
        "format": "json"
    }
    r = requests.get(API_URL, params=params, headers=HEADERS)
    data = r.json()
    members = data.get("query", {}).get("categorymembers", [])
    subcats = [m["title"] for m in members]
    if depth > 1:
        for sc in subcats:
            subcats.extend(get_subcategories(sc, depth=depth-1))
    return subcats

# Wikidata metadata
def get_wikidata_metadata(title):
    # Step 1: Get Wikidata item ID
    params = {
        "action": "query",
        "titles": title,
        "prop": "pageprops",
        "format": "json"
    }
    r = requests.get(API_URL, params=params, headers=HEADERS)
    data = r.json()
    pages = data.get("query", {}).get("pages", {})
    wikidata_id = None
    for _, page in pages.items():
        wikidata_id = page.get("pageprops", {}).get("wikibase_item")
    if not wikidata_id:
        return {}

    claims = get_claims(wikidata_id)
    metadata = {}

    # Event date
    for pid in ["P585", "P729", "P837"]:  # point in time, start time, day of year
        if pid in claims:
            try:
                if pid == "P837":  # day of year stored as QID
                    qid = claims[pid][0]["mainsnak"]["datavalue"]["value"]["id"]
                    metadata["event_date"] = get_label_from_wikidata(qid)
                else:
                    metadata["event_date"] = claims[pid][0]["mainsnak"]["datavalue"]["value"]["time"]
                break
            except:
                pass

    # Country + continent
    if "P17" in claims:  # country
        try:
            country_qid = claims["P17"][0]["mainsnak"]["datavalue"]["value"]["id"]
            metadata["country"] = get_label_from_wikidata(country_qid)
            # Look up continent from country
            country_claims = get_claims(country_qid)
            if "P30" in country_claims:
                cont_qid = country_claims["P30"][0]["mainsnak"]["datavalue"]["value"]["id"]
                metadata["continent"] = get_label_from_wikidata(cont_qid)
        except:
            pass

    return metadata

# Article creation date
def get_article_creation_date(title):
    params = {
        "action": "query",
        "titles": title,
        "prop": "revisions",
        "rvprop": "timestamp",
        "rvlimit": "1",
        "format": "json"
    }
    r = requests.get(API_URL, params=params, headers=HEADERS)
    pages = r.json().get("query", {}).get("pages", {})
    for _, page in pages.items():
        revs = page.get("revisions", [])
        if revs:
            return revs[0]["timestamp"]
    return None

# Main function: fetch all metadata
def fetch_article_metadata(title, depth=1):
    meta = {
        "article": title,
        "creation_date": get_article_creation_date(title),
    }

    # Categories + subcategories
    cats = get_article_categories(title)
    subcats = []
    for c in cats:
        subcats.extend(get_subcategories(c, depth=depth))
    meta["categories"] = cats
    meta["subcategories"] = subcats

    # Wikidata metadata
    wd_meta = get_wikidata_metadata(title)
    meta.update(wd_meta)

    return meta

# Example usage
metadata = []
for title in df_articles["title"]:  # your list of articles
    print(f"Fetching metadata for {title}...")
    try:
        info = fetch_article_metadata(title, depth=1)
        metadata.append(info)
        time.sleep(0.2)
    except Exception as e:
        print(f"Error fetching {title}: {e}")

df_meta = pd.DataFrame(metadata)
print(df_meta.head())
# Out:
# Fetching metadata for Armenian Genocide Remembrance Day...
# Fetching metadata for Black Ribbon Day...
# Fetching metadata for Circassian Day of Mourning...
# Fetching metadata for Genocide Remembrance Day (Bangladesh)...
# Fetching metadata for Holodomor Memorial Day...
# Fetching metadata for International Day of Reflection on the 1994 Rwanda Genocide...
# Fetching metadata for Martyred Intellectuals Day...
# Fetching metadata for National Day for Truth and Reconciliation...
# Fetching metadata for National Day of Remembrance (Cambodia)...
# Fetching metadata for National Sorry Day...
# Fetching metadata for White Armband Day...
#                                  article         creation_date  \
# 0      Armenian Genocide Remembrance Day  2025-06-25T04:50:21Z
# 1                       Black Ribbon Day  2025-09-16T06:47:57Z
# 2             Circassian Day of Mourning  2025-04-09T16:55:18Z
# 3  Genocide Remembrance Day (Bangladesh)  2025-07-07T22:15:07Z
# 4                 Holodomor Memorial Day  2024-10-31T01:04:31Z
#
#                                           categories  \
# 0  [Category:April observances, Category:Armenian...
# 1  [Category:1986 establishments in Canada, Categ...
# 2  [Category:1990 establishments in Russia, Categ...
# 3  [Category:1971 Bangladesh genocide, Category:A...
# 4  [Category:1998 establishments in Ukraine, Cate...
#
#                                        subcategories  \
# 0  [Category:April Fools' Day, Category:Earth Day...
# 1  [Category:1986 establishments in Alberta, Cate...
# 2  [Category:Railway stations in Russia opened in...
# 3  [Category:1971 Bangladesh genocide perpetrator...
# 4  [Category:Ukrainian companies established in 1...
#
#                     event_date  country continent
# 0                     April 24      NaN       NaN
# 1                    August 23      NaN       NaN
# 2                          NaN      NaN       NaN
# 3                     March 25      NaN       NaN
# 4  fourth Saturday in November  Ukraine    Europe

# %%
df_meta
# Out:
#                                               article         creation_date  \
# 0                   Armenian Genocide Remembrance Day  2025-06-25T04:50:21Z
# 1                                    Black Ribbon Day  2025-09-16T06:47:57Z
# 2                          Circassian Day of Mourning  2025-04-09T16:55:18Z
# 3               Genocide Remembrance Day (Bangladesh)  2025-07-07T22:15:07Z
# 4                              Holodomor Memorial Day  2024-10-31T01:04:31Z
# 5   International Day of Reflection on the 1994 Rw...  2023-05-11T10:32:53Z
# 6                          Martyred Intellectuals Day  2025-07-11T01:11:00Z
# 7           National Day for Truth and Reconciliation  2025-09-11T13:04:05Z
# 8              National Day of Remembrance (Cambodia)  2025-08-06T09:22:46Z
# 9                                  National Sorry Day  2025-08-11T06:41:50Z
# 10                                  White Armband Day  2025-07-31T23:31:31Z
#
#                                            categories  \
# 0   [Category:April observances, Category:Armenian...
# 1   [Category:1986 establishments in Canada, Categ...
# 2   [Category:1990 establishments in Russia, Categ...
# 3   [Category:1971 Bangladesh genocide, Category:A...
# 4   [Category:1998 establishments in Ukraine, Cate...
# 5   [Category:April observances, Category:Genocide...
# 6   [Category:1971 killing of Bengali intellectual...
# 7   [Category:2013 establishments in Canada, Categ...
# 8   [Category:Aftermath of the Cambodian genocide,...
# 9   [Category:All Wikipedia articles written in Au...
# 10  [Category:1992 in Bosnia and Herzegovina, Cate...
#
#                                         subcategories  \
# 0   [Category:April Fools' Day, Category:Earth Day...
# 1   [Category:1986 establishments in Alberta, Cate...
# 2   [Category:Railway stations in Russia opened in...
# 3   [Category:1971 Bangladesh genocide perpetrator...
# 4   [Category:Ukrainian companies established in 1...
# 5   [Category:April Fools' Day, Category:Earth Day...
# 6   [Category:Short description is different from ...
# 7   [Category:Canadian companies established in 20...
# 8   [Category:Cambodian–Vietnamese War, Category:K...
# 9   [Category:Short description is different from ...
# 10  [Category:1992 disestablishments in Bosnia and...
#
#                      event_date                 country      continent
# 0                      April 24                     NaN            NaN
# 1                     August 23                     NaN            NaN
# 2                           NaN                     NaN            NaN
# 3                      March 25                     NaN            NaN
# 4   fourth Saturday in November                 Ukraine         Europe
# 5                       April 7                     NaN            NaN
# 6                   December 14                     NaN            NaN
# 7                  September 30                  Canada  North America
# 8                        May 20                Cambodia           Asia
# 9                        May 26               Australia        Oceania
# 10                       May 31  Bosnia and Herzegovina         Europe

# %%
df_meta = df_meta[['article', 'event_date']]

# %%
df_meta = pd.read_csv("df_meta.csv")

# %%
df_articles = df_articles.rename(columns = { "title" : "article"})

# %%
df_meta= pd.merge(df_meta, df_articles, how = "right", on= ["article"])

# %%
################
df_meta = df_articles.merge(
    df_meta,
    on="article",  
    how="left"     
)

# %%
cols_to_add = ["article", "country", "continent", "categories", "subcategories", "event_date", "country", "continent"]
df_merged = df_articles.merge(
    df_meta[cols_to_add],
    on="article",
    how="left"
)

# %%
df_merged
# Out:
#       pageid                                article          Categorie  \
# 0    4575104      Armenian Genocide Remembrance Day           Genocide
# 1   25966474                       Black Ribbon Day           Genocide
# 2   17539056             Circassian Day of Mourning           Genocide
# 3   53453368  Genocide Remembrance Day (Bangladesh)           Genocide
# 4   69380022                 Holodomor Memorial Day           Genocide
# ..       ...                                    ...                ...
# 94  44244013                 Victory Day (Maldives)  Independence days
# 95    215257                  Victory in Europe Day  Independence days
# 96  57115772         Victory in Europe Day (Israel)  Independence days
# 97  17678597                              Võidupüha  Independence days
# 98   1640108                           Waterloo Day  Independence days
#
#                                          categories_x  \
# 0   ['Category:April observances', 'Category:Armen...
# 1   ['Category:1986 establishments in Canada', 'Ca...
# 2                                                 NaN
# 3   ['Category:1971 Bangladesh genocide', 'Categor...
# 4   ['Category:1998 establishments in Ukraine', 'C...
# ..                                                ...
# 94                                                NaN
# 95  ['Category:1945 in Europe', 'Category:All arti...
# 96                                                NaN
# 97  ['Category:All articles needing additional ref...
# 98  ['Category:All stub articles', 'Category:Annua...
#
#                                       subcategories_x  \
# 0   ["Category:April Fools' Day", 'Category:Earth ...
# 1   ['Category:1986 establishments in Alberta', 'C...
# 2                                                 NaN
# 3   ['Category:1971 Bangladesh genocide perpetrato...
# 4   ['Category:Ukrainian companies established in ...
# ..                                                ...
# 94                                                NaN
# 95  ['Category:1945 crimes in Europe', 'Category:1...
# 96                                                NaN
# 97  ['Category:New York City public transportation...
# 98  ['Category:Long stubs with short prose', 'Cate...
#
#                    event_date_x                          country_x  \
# 0                      April 24                                NaN
# 1                     August 23                                NaN
# 2                           NaN                                NaN
# 3                      March 25                                NaN
# 4   fourth Saturday in November                            Ukraine
# ..                          ...                                ...
# 94                          NaN                                NaN
# 95        +1945-05-08T00:00:00Z                             France
# 96                          NaN                                NaN
# 97                      June 23                            Estonia
# 98                      June 18  United Kingdom of the Netherlands
#
#    continent_x                                    event_windows_x  \
# 0          NaN  {2015: ['2015-04-21', '2015-04-27'], 2016: ['2...
# 1          NaN  {2015: ['2015-08-20', '2015-08-26'], 2016: ['2...
# 2          NaN                                                NaN
# 3          NaN  {2015: ['2015-03-22', '2015-03-28'], 2016: ['2...
# 4       Europe                                               None
# ..         ...                                                ...
# 94         NaN                                                NaN
# 95      Europe                                               None
# 96         NaN                                                NaN
# 97      Europe  {2015: ['2015-06-20', '2015-06-26'], 2016: ['2...
# 98      Europe  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
#
#                                          categories_y  ...  \
# 0   ['Category:April observances', 'Category:Armen...  ...
# 1   ['Category:1986 establishments in Canada', 'Ca...  ...
# 2                                                 NaN  ...
# 3   ['Category:1971 Bangladesh genocide', 'Categor...  ...
# 4   ['Category:1998 establishments in Ukraine', 'C...  ...
# ..                                                ...  ...
# 94                                                NaN  ...
# 95  ['Category:1945 in Europe', 'Category:All arti...  ...
# 96                                                NaN  ...
# 97  ['Category:All articles needing additional ref...  ...
# 98  ['Category:All stub articles', 'Category:Annua...  ...
#
#                             country_y continent_y  \
# 0                                 NaN         NaN
# 1                                 NaN         NaN
# 2                                 NaN         NaN
# 3                                 NaN         NaN
# 4                             Ukraine      Europe
# ..                                ...         ...
# 94                                NaN         NaN
# 95                             France      Europe
# 96                                NaN         NaN
# 97                            Estonia      Europe
# 98  United Kingdom of the Netherlands      Europe
#
#                                       event_windows_y  \
# 0   {2015: ['2015-04-21', '2015-04-27'], 2016: ['2...
# 1   {2015: ['2015-08-20', '2015-08-26'], 2016: ['2...
# 2                                                 NaN
# 3   {2015: ['2015-03-22', '2015-03-28'], 2016: ['2...
# 4                                                None
# ..                                                ...
# 94                                                NaN
# 95                                               None
# 96                                                NaN
# 97  {2015: ['2015-06-20', '2015-06-26'], 2016: ['2...
# 98  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
#
#                               country continent  \
# 0                                 NaN       NaN
# 1                                 NaN       NaN
# 2                                 NaN       NaN
# 3                                 NaN       NaN
# 4                             Ukraine    Europe
# ..                                ...       ...
# 94                                NaN       NaN
# 95                             France    Europe
# 96                             Israel      Asia
# 97                            Estonia    Europe
# 98  United Kingdom of the Netherlands    Europe
#
#                                            categories  \
# 0   ['Category:April observances', 'Category:Armen...
# 1   ['Category:1986 establishments in Canada', 'Ca...
# 2   ['Category:1990 establishments in Russia', 'Ca...
# 3   ['Category:1971 Bangladesh genocide', 'Categor...
# 4   ['Category:1998 establishments in Ukraine', 'C...
# ..                                                ...
# 94  ['Category:Annual events in the Maldives', 'Ca...
# 95  ['Category:1945 in Europe', 'Category:All arti...
# 96  ['Category:All articles with unsourced stateme...
# 97  ['Category:All articles needing additional ref...
# 98  ['Category:All stub articles', 'Category:Annua...
#
#                                         subcategories  \
# 0   ["Category:April Fools' Day", 'Category:Earth ...
# 1   ['Category:1986 establishments in Alberta', 'C...
# 2   ['Category:Railway stations in Russia opened i...
# 3   ['Category:1971 Bangladesh genocide perpetrato...
# 4   ['Category:Ukrainian companies established in ...
# ..                                                ...
# 94  ['Category:Short description is different from...
# 95  ['Category:1945 crimes in Europe', 'Category:1...
# 96  ['Category:Articles containing Biblical Hebrew...
# 97  ['Category:New York City public transportation...
# 98  ['Category:Long stubs with short prose', 'Cate...
#
#                      event_date                            country continent
# 0                      April 24                                NaN       NaN
# 1                     August 23                                NaN       NaN
# 2                           NaN                                NaN       NaN
# 3                      March 25                                NaN       NaN
# 4   fourth Saturday in November                            Ukraine    Europe
# ..                          ...                                ...       ...
# 94                          NaN                                NaN       NaN
# 95        +1945-05-08T00:00:00Z                             France    Europe
# 96                          NaN                             Israel      Asia
# 97                      June 23                            Estonia    Europe
# 98                      June 18  United Kingdom of the Netherlands    Europe
#
# [99 rows x 22 columns]

# %%
df_meta = df_meta.drop('creation_date', axis=1)

# %%
df_meta = df_meta.dropna(subset=['event_date'])

# %%
df_meta
# Out:
#                                               article  \
# 0                   Armenian Genocide Remembrance Day
# 1                                    Black Ribbon Day
# 2                          Circassian Day of Mourning
# 3               Genocide Remembrance Day (Bangladesh)
# 4                              Holodomor Memorial Day
# 5   International Day of Reflection on the 1994 Rw...
# 6                          Martyred Intellectuals Day
# 7           National Day for Truth and Reconciliation
# 8              National Day of Remembrance (Cambodia)
# 9                                  National Sorry Day
# 10                                  White Armband Day
#
#                      event_date  \
# 0                      April 24
# 1                     August 23
# 2                           NaN
# 3                      March 25
# 4   fourth Saturday in November
# 5                       April 7
# 6                   December 14
# 7                  September 30
# 8                        May 20
# 9                        May 26
# 10                       May 31
#
#                                         event_windows
# 0   {2016: ['2016-04-21', '2016-04-27'], 2017: ['2...
# 1   {2016: ['2016-08-20', '2016-08-26'], 2017: ['2...
# 2                                                None
# 3   {2016: ['2016-03-22', '2016-03-28'], 2017: ['2...
# 4                                                None
# 5   {2016: ['2016-04-04', '2016-04-10'], 2017: ['2...
# 6   {2016: ['2016-12-11', '2016-12-17'], 2017: ['2...
# 7   {2016: ['2016-09-27', '2016-10-03'], 2017: ['2...
# 8   {2016: ['2016-05-17', '2016-05-23'], 2017: ['2...
# 9   {2016: ['2016-05-23', '2016-05-29'], 2017: ['2...
# 10  {2016: ['2016-05-28', '2016-06-03'], 2017: ['2...

# %%
page_views["article"] = page_views["article"].str.replace('_', ' ')

# %% [markdown]
# <h1 style="font-size:-large">Creating a 7-day Window for the Event</h1>

# %%
def make_window(event_date_str, years, window=3):
    try:
        # Try parsing as fixed day/month (e.g., "April 24")
        base = pd.to_datetime(event_date_str + " 2000", format="%B %d %Y")
        windows = {
            year: [
                (base.replace(year=year) - timedelta(days=window)).strftime("%Y-%m-%d"),
                (base.replace(year=year) + timedelta(days=window)).strftime("%Y-%m-%d"),
            ]
            for year in years
        }
        return windows
    except Exception:
        # Handle "movable" holidays separately later
        return None

# Example: generate windows for 2015–2025
years = range(2016, 2026)
df_meta["event_windows"] = df_meta["event_date"].apply(lambda d: make_window(d, years))

print(df_meta[["article", "event_date", "event_windows"]])
# Out:
#                                               article  \
# 0                   Armenian Genocide Remembrance Day
# 1                                    Black Ribbon Day
# 2                          Circassian Day of Mourning
# 3               Genocide Remembrance Day (Bangladesh)
# 4                              Holodomor Memorial Day
# 5   International Day of Reflection on the 1994 Rw...
# 6                          Martyred Intellectuals Day
# 7           National Day for Truth and Reconciliation
# 8              National Day of Remembrance (Cambodia)
# 9                                  National Sorry Day
# 10                                  White Armband Day
#
#                      event_date  \
# 0                      April 24
# 1                     August 23
# 2                           NaN
# 3                      March 25
# 4   fourth Saturday in November
# 5                       April 7
# 6                   December 14
# 7                  September 30
# 8                        May 20
# 9                        May 26
# 10                       May 31
#
#                                         event_windows
# 0   {2016: ['2016-04-21', '2016-04-27'], 2017: ['2...
# 1   {2016: ['2016-08-20', '2016-08-26'], 2017: ['2...
# 2                                                None
# 3   {2016: ['2016-03-22', '2016-03-28'], 2017: ['2...
# 4                                                None
# 5   {2016: ['2016-04-04', '2016-04-10'], 2017: ['2...
# 6   {2016: ['2016-12-11', '2016-12-17'], 2017: ['2...
# 7   {2016: ['2016-09-27', '2016-10-03'], 2017: ['2...
# 8   {2016: ['2016-05-17', '2016-05-23'], 2017: ['2...
# 9   {2016: ['2016-05-23', '2016-05-29'], 2017: ['2...
# 10  {2016: ['2016-05-28', '2016-06-03'], 2017: ['2...
# C:\Users\daihe\AppData\Local\Temp\ipykernel_4600\518347159.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meta["event_windows"] = df_meta["event_date"].apply(lambda d: make_window(d, years))

# %% [markdown]
# <h1 style="font-size:-large">Merging Dataframes</h1>

# %%
merged = page_views.merge(
    df_meta,
    on="article",  
    how="left"      # keep all page_views rows
)

# %%
#######################
#different try 
merged = page_views.merge(
    df_merged,
    on="article",  
    how="left"      # keep all page_views rows
)

# %%
merged
# Out:
#              date  views         article   pageid          Categorie  \
# 0      2016-01-01    205  Liberation Day  1106409  Independence days
# 1      2016-01-01    205  Liberation Day  1106409  Independence days
# 2      2016-01-02    111  Liberation Day  1106409  Independence days
# 3      2016-01-02    111  Liberation Day  1106409  Independence days
# 4      2016-01-03     82  Liberation Day  1106409  Independence days
# ...           ...    ...             ...      ...                ...
# 179106 2024-12-30      9    Waterloo Day  1640108  Independence days
# 179107 2024-12-31      8    Waterloo Day  1640108  Independence days
# 179108 2024-12-31      8    Waterloo Day  1640108  Independence days
# 179109 2025-01-01      2    Waterloo Day  1640108  Independence days
# 179110 2025-01-01      2    Waterloo Day  1640108  Independence days
#
#                                              categories_x  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 179106  ['Category:All stub articles', 'Category:Annua...
# 179107  ['Category:All stub articles', 'Category:Annua...
# 179108  ['Category:All stub articles', 'Category:Annua...
# 179109  ['Category:All stub articles', 'Category:Annua...
# 179110  ['Category:All stub articles', 'Category:Annua...
#
#                                           subcategories_x event_date_x  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 179106  ['Category:Long stubs with short prose', 'Cate...      June 18
# 179107  ['Category:Long stubs with short prose', 'Cate...      June 18
# 179108  ['Category:Long stubs with short prose', 'Cate...      June 18
# 179109  ['Category:Long stubs with short prose', 'Cate...      June 18
# 179110  ['Category:Long stubs with short prose', 'Cate...      June 18
#
#                                 country_x continent_x  ...  \
# 0                                     NaN         NaN  ...
# 1                                     NaN         NaN  ...
# 2                                     NaN         NaN  ...
# 3                                     NaN         NaN  ...
# 4                                     NaN         NaN  ...
# ...                                   ...         ...  ...
# 179106  United Kingdom of the Netherlands      Europe  ...
# 179107  United Kingdom of the Netherlands      Europe  ...
# 179108  United Kingdom of the Netherlands      Europe  ...
# 179109  United Kingdom of the Netherlands      Europe  ...
# 179110  United Kingdom of the Netherlands      Europe  ...
#
#                                 country_y continent_y  \
# 0                                     NaN         NaN
# 1                                     NaN         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
# ...                                   ...         ...
# 179106  United Kingdom of the Netherlands      Europe
# 179107  United Kingdom of the Netherlands      Europe
# 179108  United Kingdom of the Netherlands      Europe
# 179109  United Kingdom of the Netherlands      Europe
# 179110  United Kingdom of the Netherlands      Europe
#
#                                           event_windows_y  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 179106  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179107  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179108  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179109  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179110  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
#
#                                   country continent  \
# 0                                     NaN       NaN
# 1                                     NaN       NaN
# 2                                     NaN       NaN
# 3                                     NaN       NaN
# 4                                     NaN       NaN
# ...                                   ...       ...
# 179106  United Kingdom of the Netherlands    Europe
# 179107  United Kingdom of the Netherlands    Europe
# 179108  United Kingdom of the Netherlands    Europe
# 179109  United Kingdom of the Netherlands    Europe
# 179110  United Kingdom of the Netherlands    Europe
#
#                                                categories  \
# 0       ['Category:April observances', 'Category:Artic...
# 1       ['Category:April observances', 'Category:Artic...
# 2       ['Category:April observances', 'Category:Artic...
# 3       ['Category:April observances', 'Category:Artic...
# 4       ['Category:April observances', 'Category:Artic...
# ...                                                   ...
# 179106  ['Category:All stub articles', 'Category:Annua...
# 179107  ['Category:All stub articles', 'Category:Annua...
# 179108  ['Category:All stub articles', 'Category:Annua...
# 179109  ['Category:All stub articles', 'Category:Annua...
# 179110  ['Category:All stub articles', 'Category:Annua...
#
#                                             subcategories event_date  \
# 0       ["Category:April Fools' Day", 'Category:Earth ...        NaN
# 1       ["Category:April Fools' Day", 'Category:Earth ...        NaN
# 2       ["Category:April Fools' Day", 'Category:Earth ...        NaN
# 3       ["Category:April Fools' Day", 'Category:Earth ...        NaN
# 4       ["Category:April Fools' Day", 'Category:Earth ...        NaN
# ...                                                   ...        ...
# 179106  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179107  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179108  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179109  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179110  ['Category:Long stubs with short prose', 'Cate...    June 18
#
#                                   country continent
# 0                                     NaN       NaN
# 1                                     NaN       NaN
# 2                                     NaN       NaN
# 3                                     NaN       NaN
# 4                                     NaN       NaN
# ...                                   ...       ...
# 179106  United Kingdom of the Netherlands    Europe
# 179107  United Kingdom of the Netherlands    Europe
# 179108  United Kingdom of the Netherlands    Europe
# 179109  United Kingdom of the Netherlands    Europe
# 179110  United Kingdom of the Netherlands    Europe
#
# [179111 rows x 24 columns]

# %%
merged
# Out:
#              date  views         article   pageid          Categorie  \
# 0      2016-01-01    205  Liberation Day  1106409  Independence days
# 1      2016-01-01    205  Liberation Day  1106409  Independence days
# 2      2016-01-02    111  Liberation Day  1106409  Independence days
# 3      2016-01-02    111  Liberation Day  1106409  Independence days
# 4      2016-01-03     82  Liberation Day  1106409  Independence days
# ...           ...    ...             ...      ...                ...
# 179106 2024-12-30      9    Waterloo Day  1640108  Independence days
# 179107 2024-12-31      8    Waterloo Day  1640108  Independence days
# 179108 2024-12-31      8    Waterloo Day  1640108  Independence days
# 179109 2025-01-01      2    Waterloo Day  1640108  Independence days
# 179110 2025-01-01      2    Waterloo Day  1640108  Independence days
#
#                                                categories  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 179106  ['Category:All stub articles', 'Category:Annua...
# 179107  ['Category:All stub articles', 'Category:Annua...
# 179108  ['Category:All stub articles', 'Category:Annua...
# 179109  ['Category:All stub articles', 'Category:Annua...
# 179110  ['Category:All stub articles', 'Category:Annua...
#
#                                             subcategories event_date  \
# 0                                                     NaN        NaN
# 1                                                     NaN        NaN
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4                                                     NaN        NaN
# ...                                                   ...        ...
# 179106  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179107  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179108  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179109  ['Category:Long stubs with short prose', 'Cate...    June 18
# 179110  ['Category:Long stubs with short prose', 'Cate...    June 18
#
#                                   country continent  \
# 0                                     NaN       NaN
# 1                                     NaN       NaN
# 2                                     NaN       NaN
# 3                                     NaN       NaN
# 4                                     NaN       NaN
# ...                                   ...       ...
# 179106  United Kingdom of the Netherlands    Europe
# 179107  United Kingdom of the Netherlands    Europe
# 179108  United Kingdom of the Netherlands    Europe
# 179109  United Kingdom of the Netherlands    Europe
# 179110  United Kingdom of the Netherlands    Europe
#
#                                             event_windows
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 179106  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179107  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179108  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179109  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
# 179110  {2015: ['2015-06-15', '2015-06-21'], 2016: ['2...
#
# [179111 rows x 11 columns]

# %%
page_views.duplicated(subset=["article", "date"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h1 style="font-size:-large">Creating Boolean on whether Pageview is in event window or not</h1>

# %%
merged.to_csv("final_df.csv")

# %%
merged = pd.read_csv("final_df.csv")

# %% [markdown]
# <h1 style="font-size:-large">Setting threshold (original paper kept only top 11 sources)</h1>

# %%
merged[merged["article"] == "Armenian Genocide Remembrance Day"].shape[0]
# Out:
# 3289

# %%
# Count number of rows per article
counts = merged["article"].value_counts()

# Get articles with exactly 3289 rows
valid_articles = counts[counts == 3289].index

# Filter the dataframe
merged = merged[merged["article"].isin(valid_articles)]

# %%
merged
# Out:
# Empty DataFrame
# Columns: [date, views, article, pageid, Categorie, categories, subcategories, event_date, country, continent, event_windows]
# Index: []

# %%
# Calculate average daily views per article
avg_views = merged.groupby('article')['views'].mean()

threshold = avg_views.quantile(0.3)  
high_traffic_articles = avg_views[avg_views >= threshold].index

# Filter  dataset
df_filtered = merged[merged['article'].isin(high_traffic_articles)]

# %%
# Compute average views per article
avg_views = merged.groupby("article")["views"].mean()

# Keep only articles with avg >= 100
articles_to_keep = avg_views[avg_views >= 100].index
df_filtered = merged[merged["article"].isin(articles_to_keep)]

# %%
exclude_articles = [
    'List of countries that have gained independence from the United Kingdom',
    'List of national independence days', 'Liberation Day'
]

df_filtered = df_filtered[~df_filtered["article"].isin(exclude_articles)]

# %%
df_filtered
# Out:
#              date  views                article  \
# 9853   2016-01-01   1363          Cinco de Mayo
# 9854   2016-01-02   1010          Cinco de Mayo
# 9855   2016-01-03   1066          Cinco de Mayo
# 9856   2016-01-04   1193          Cinco de Mayo
# 9857   2016-01-05   1251          Cinco de Mayo
# ...           ...    ...                    ...
# 747128 2024-12-28   1178  Victory in Europe Day
# 747129 2024-12-29   1113  Victory in Europe Day
# 747130 2024-12-30   1205  Victory in Europe Day
# 747131 2024-12-31   1083  Victory in Europe Day
# 747132 2025-01-01   1202  Victory in Europe Day
#
#                                                categories  \
# 9853    ['Category:1862 establishments in Mexico', 'Ca...
# 9854    ['Category:1862 establishments in Mexico', 'Ca...
# 9855    ['Category:1862 establishments in Mexico', 'Ca...
# 9856    ['Category:1862 establishments in Mexico', 'Ca...
# 9857    ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                   ...
# 747128  ['Category:1945 in Europe', 'Category:All arti...
# 747129  ['Category:1945 in Europe', 'Category:All arti...
# 747130  ['Category:1945 in Europe', 'Category:All arti...
# 747131  ['Category:1945 in Europe', 'Category:All arti...
# 747132  ['Category:1945 in Europe', 'Category:All arti...
#
#                                             subcategories event_date country  \
# 9853    ['Category:Short description is different from...      May 5  Mexico
# 9854    ['Category:Short description is different from...      May 5  Mexico
# 9855    ['Category:Short description is different from...      May 5  Mexico
# 9856    ['Category:Short description is different from...      May 5  Mexico
# 9857    ['Category:Short description is different from...      May 5  Mexico
# ...                                                   ...        ...     ...
# 747128  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747129  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747130  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747131  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747132  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
#
#             continent      pageid  \
# 9853    North America  26482586.0
# 9854    North America  26482586.0
# 9855    North America  26482586.0
# 9856    North America  26482586.0
# 9857    North America  26482586.0
# ...               ...         ...
# 747128         Europe    215257.0
# 747129         Europe    215257.0
# 747130         Europe    215257.0
# 747131         Europe    215257.0
# 747132         Europe    215257.0
#
#                                                     links  \
# 9853    [420 (cannabis culture), Abbotsford, British C...
# 9854    [420 (cannabis culture), Abbotsford, British C...
# 9855    [420 (cannabis culture), Abbotsford, British C...
# 9856    [420 (cannabis culture), Abbotsford, British C...
# 9857    [420 (cannabis culture), Abbotsford, British C...
# ...                                                   ...
# 747128  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747129  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747130  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747131  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747132  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
#
#                                             event_windows
# 9853    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9854    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9855    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9856    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9857    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...                                                   ...
# 747128  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747129  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747130  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747131  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747132  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
# [151294 rows x 11 columns]

# %%
pd.set_option('display.max_rows', 60)    # Reset to default (or any number)

# %%
pd.set_option('display.max_rows', 10)    # Reset to default (or any number)

# %% [markdown]
# <h1 style="font-size:-large">Creating Source Target Pairs</h1>

# %%
# Create source-target pairs
source_events = df_filtered['article'].unique()  # All memorial days
for source in source_events:
    targets = [day for day in source_events if day != source]  # All others except self

# %%
pairs = [(source, target) for source in source_events 
                            for target in source_events if target != source]

# %%
df_filtered
# Out:
#              date  views                article  \
# 9853   2016-01-01   1363          Cinco de Mayo
# 9854   2016-01-02   1010          Cinco de Mayo
# 9855   2016-01-03   1066          Cinco de Mayo
# 9856   2016-01-04   1193          Cinco de Mayo
# 9857   2016-01-05   1251          Cinco de Mayo
# ...           ...    ...                    ...
# 747128 2024-12-28   1178  Victory in Europe Day
# 747129 2024-12-29   1113  Victory in Europe Day
# 747130 2024-12-30   1205  Victory in Europe Day
# 747131 2024-12-31   1083  Victory in Europe Day
# 747132 2025-01-01   1202  Victory in Europe Day
#
#                                                categories  \
# 9853    ['Category:1862 establishments in Mexico', 'Ca...
# 9854    ['Category:1862 establishments in Mexico', 'Ca...
# 9855    ['Category:1862 establishments in Mexico', 'Ca...
# 9856    ['Category:1862 establishments in Mexico', 'Ca...
# 9857    ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                   ...
# 747128  ['Category:1945 in Europe', 'Category:All arti...
# 747129  ['Category:1945 in Europe', 'Category:All arti...
# 747130  ['Category:1945 in Europe', 'Category:All arti...
# 747131  ['Category:1945 in Europe', 'Category:All arti...
# 747132  ['Category:1945 in Europe', 'Category:All arti...
#
#                                             subcategories event_date country  \
# 9853    ['Category:Short description is different from...      May 5  Mexico
# 9854    ['Category:Short description is different from...      May 5  Mexico
# 9855    ['Category:Short description is different from...      May 5  Mexico
# 9856    ['Category:Short description is different from...      May 5  Mexico
# 9857    ['Category:Short description is different from...      May 5  Mexico
# ...                                                   ...        ...     ...
# 747128  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747129  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747130  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747131  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 747132  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
#
#             continent      pageid  \
# 9853    North America  26482586.0
# 9854    North America  26482586.0
# 9855    North America  26482586.0
# 9856    North America  26482586.0
# 9857    North America  26482586.0
# ...               ...         ...
# 747128         Europe    215257.0
# 747129         Europe    215257.0
# 747130         Europe    215257.0
# 747131         Europe    215257.0
# 747132         Europe    215257.0
#
#                                                     links  \
# 9853    [420 (cannabis culture), Abbotsford, British C...
# 9854    [420 (cannabis culture), Abbotsford, British C...
# 9855    [420 (cannabis culture), Abbotsford, British C...
# 9856    [420 (cannabis culture), Abbotsford, British C...
# 9857    [420 (cannabis culture), Abbotsford, British C...
# ...                                                   ...
# 747128  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747129  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747130  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747131  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 747132  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
#
#                                             event_windows
# 9853    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9854    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9855    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9856    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 9857    {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...                                                   ...
# 747128  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747129  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747130  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747131  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 747132  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
# [151294 rows x 11 columns]

# %%
df_filtered = df_meta

# %% [markdown]
# <h1 style="font-size:-large">Mapping missing event days</h1>

# %%
df_filtered.loc[df_filtered["article"] == "Nakba Day", "event_date"] = "May 15"
df_filtered.loc[df_filtered["article"] == "Celebration of the Greek Revolution", "event_date"] = "March 25"
df_filtered.loc[df_filtered["article"] == "Grito de Lares", "event_date"] = "September 23"
df_filtered.loc[df_filtered["article"] == "Victory over Japan Day", "event_date"] = "August 15"
df_filtered.loc[df_filtered["article"] == "Victory in Europe Day", "event_date"] = "May 8"
df_filtered.loc[df_filtered["article"] == "Remembrance Sunday", "event_date"] = "November 9"
df_filtered.loc[df_filtered["article"] == "Victory Day", "event_date"] = "May 9"
df_filtered.loc[df_filtered["article"] == "Circassian Day of Mourning", "event_date"] = "May 21"
df_filtered.loc[df_filtered["article"] == "Circassian Day of Mourning", "event_date"] = "May 21"

# %%
#print(df_filtered[df_filtered['event_windows'].isnull()])
#df_filtered = df_filtered.dropna(subset = ['event_windows'], inplace=True)
# Out:
#         Unnamed: 0                article         creation_date  \
# 317163      317163            Yom HaShoah  2004-03-19T07:08:56Z
# 317164      317164            Yom HaShoah  2004-03-19T07:08:56Z
# 317165      317165            Yom HaShoah  2004-03-19T07:08:56Z
# 317166      317166            Yom HaShoah  2004-03-19T07:08:56Z
# 317167      317167            Yom HaShoah  2004-03-19T07:08:56Z
# ...            ...                    ...                   ...
# 781117      781117  Victory in Europe Day  2003-04-24T03:52:57Z
# 781118      781118  Victory in Europe Day  2003-04-24T03:52:57Z
# 781119      781119  Victory in Europe Day  2003-04-24T03:52:57Z
# 781120      781120  Victory in Europe Day  2003-04-24T03:52:57Z
# 781121      781121  Victory in Europe Day  2003-04-24T03:52:57Z
#
#                                                categories  \
# 317163  ['Category:Articles containing Hebrew-language...
# 317164  ['Category:Articles containing Hebrew-language...
# 317165  ['Category:Articles containing Hebrew-language...
# 317166  ['Category:Articles containing Hebrew-language...
# 317167  ['Category:Articles containing Hebrew-language...
# ...                                                   ...
# 781117  ['Category:1945 in Europe', 'Category:All arti...
# 781118  ['Category:1945 in Europe', 'Category:All arti...
# 781119  ['Category:1945 in Europe', 'Category:All arti...
# 781120  ['Category:1945 in Europe', 'Category:All arti...
# 781121  ['Category:1945 in Europe', 'Category:All arti...
#
#                                             subcategories event_date country  \
# 317163  ['Category:Articles containing Biblical Hebrew...   27 Nisan  Israel
# 317164  ['Category:Articles containing Biblical Hebrew...   27 Nisan  Israel
# 317165  ['Category:Articles containing Biblical Hebrew...   27 Nisan  Israel
# 317166  ['Category:Articles containing Biblical Hebrew...   27 Nisan  Israel
# 317167  ['Category:Articles containing Biblical Hebrew...   27 Nisan  Israel
# ...                                                   ...        ...     ...
# 781117  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781118  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781119  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781120  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781121  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
#
#        continent event_windows        date   views  pageid  \
# 317163      Asia           NaN  2015-07-01    51.0  536854
# 317164      Asia           NaN  2015-07-02    72.0  536854
# 317165      Asia           NaN  2015-07-03   114.0  536854
# 317166      Asia           NaN  2015-07-04    98.0  536854
# 317167      Asia           NaN  2015-07-05    75.0  536854
# ...          ...           ...         ...     ...     ...
# 781117    Europe           NaN  2025-01-03  1067.0  215257
# 781118    Europe           NaN  2025-01-04  1077.0  215257
# 781119    Europe           NaN  2025-01-05  1225.0  215257
# 781120    Europe           NaN  2025-01-06  1115.0  215257
# 781121    Europe           NaN  2025-01-07  1057.0  215257
#
#                                                     links  is_event_window
# 317163  ['1941 Odessa massacre', 'Adar', 'Adolf Eichma...            False
# 317164  ['1941 Odessa massacre', 'Adar', 'Adolf Eichma...            False
# 317165  ['1941 Odessa massacre', 'Adar', 'Adolf Eichma...            False
# 317166  ['1941 Odessa massacre', 'Adar', 'Adolf Eichma...            False
# 317167  ['1941 Odessa massacre', 'Adar', 'Adolf Eichma...            False
# ...                                                   ...              ...
# 781117  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781118  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781119  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781120  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781121  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
#
# [25215 rows x 14 columns]
# C:\Users\daihe\AppData\Local\Temp\ipykernel_7296\1395364199.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered = df_filtered.dropna(subset = ['event_windows'], inplace=True)

# %%
def make_window(event_date_str, years, window=3):
    try:
        # Try parsing as fixed day/month (e.g., "April 24")
        base = pd.to_datetime(event_date_str + " 2000", format="%B %d %Y")
        windows = {
            year: [
                (base.replace(year=year) - timedelta(days=window)).strftime("%Y-%m-%d"),
                (base.replace(year=year) + timedelta(days=window)).strftime("%Y-%m-%d"),
            ]
            for year in years
        }
        return windows
    except Exception:
        # Handle "movable" holidays separately later
        return None

# Example: generate windows for 2015–2025
years = range(2015, 2025)
df_filtered["event_windows"] = df_filtered["event_date"].apply(lambda d: make_window(d, years))

print(df_filtered[["article", "event_date", "event_windows"]])
# Out:
#                                               article  \
# 0                   Armenian Genocide Remembrance Day
# 1                                    Black Ribbon Day
# 2                          Circassian Day of Mourning
# 3               Genocide Remembrance Day (Bangladesh)
# 4                              Holodomor Memorial Day
# 5   International Day of Reflection on the 1994 Rw...
# 6                          Martyred Intellectuals Day
# 7           National Day for Truth and Reconciliation
# 8              National Day of Remembrance (Cambodia)
# 9                                  National Sorry Day
# 10                                  White Armband Day
#
#                      event_date  \
# 0                      April 24
# 1                     August 23
# 2                        May 21
# 3                      March 25
# 4   fourth Saturday in November
# 5                       April 7
# 6                   December 14
# 7                  September 30
# 8                        May 20
# 9                        May 26
# 10                       May 31
#
#                                         event_windows
# 0   {2015: ['2015-04-21', '2015-04-27'], 2016: ['2...
# 1   {2015: ['2015-08-20', '2015-08-26'], 2016: ['2...
# 2   {2015: ['2015-05-18', '2015-05-24'], 2016: ['2...
# 3   {2015: ['2015-03-22', '2015-03-28'], 2016: ['2...
# 4                                                None
# 5   {2015: ['2015-04-04', '2015-04-10'], 2016: ['2...
# 6   {2015: ['2015-12-11', '2015-12-17'], 2016: ['2...
# 7   {2015: ['2015-09-27', '2015-10-03'], 2016: ['2...
# 8   {2015: ['2015-05-17', '2015-05-23'], 2016: ['2...
# 9   {2015: ['2015-05-23', '2015-05-29'], 2016: ['2...
# 10  {2015: ['2015-05-28', '2015-06-03'], 2016: ['2...
# C:\Users\daihe\AppData\Local\Temp\ipykernel_4600\3212583165.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["event_windows"] = df_filtered["event_date"].apply(lambda d: make_window(d, years))

# %%
jerusalem_day_windows = {
    2015: ['2015-05-21', '2015-05-21'],
    2016: ['2016-06-05', '2016-06-05'],
    2017: ['2017-05-29', '2017-05-29'],
    2018: ['2018-05-20', '2018-05-20'],
    2019: ['2019-05-12', '2019-05-12'],
    2020: ['2020-05-28', '2020-05-28'],
    2021: ['2021-05-10', '2021-05-10'],
    2022: ['2022-05-29', '2022-05-29'],
    2023: ['2023-05-18', '2023-05-18'],
    2024: ['2024-06-04', '2024-06-04'],
    2025: ['2025-05-27', '2025-05-27']
}

# Yom HaShoah (27 Nisan)
yom_hashoah_windows = {
    2015: ['2015-04-20', '2015-04-26'],
    2016: ['2016-05-04', '2016-05-10'],
    2017: ['2017-04-24', '2017-04-30'],
    2018: ['2018-04-11', '2018-04-17'],
    2019: ['2019-05-01', '2019-05-07'],
    2020: ['2020-04-19', '2020-04-25'],
    2021: ['2021-04-07', '2021-04-13'],
    2022: ['2022-04-27', '2022-05-03'],
    2023: ['2023-04-16', '2023-04-22'],
    2024: ['2024-05-05', '2024-05-11'],
    2025: ['2025-04-22', '2025-04-28']
}

# Memorial Day (last Monday in May)
memorial_day_windows = {
    2015: ['2015-05-25', '2015-05-25'],
    2016: ['2016-05-30', '2016-05-30'],
    2017: ['2017-05-29', '2017-05-29'],
    2018: ['2018-05-28', '2018-05-28'],
    2019: ['2019-05-27', '2019-05-27'],
    2020: ['2020-05-25', '2020-05-25'],
    2021: ['2021-05-31', '2021-05-31'],
    2022: ['2022-05-30', '2022-05-30'],
    2023: ['2023-05-29', '2023-05-29'],
    2024: ['2024-05-27', '2024-05-27'],
    2025: ['2025-05-26', '2025-05-26']
}

# Independence Day (Israel, 5 Iyar)
independence_day_windows = {
    2015: ['2015-04-22', '2015-04-22'],
    2016: ['2016-05-12', '2016-05-12'],
    2017: ['2017-04-25', '2017-04-25'],
    2018: ['2018-04-19', '2018-04-19'],
    2019: ['2019-04-29', '2019-04-29'],
    2020: ['2020-04-28', '2020-04-28'],
    2021: ['2021-04-15', '2021-04-15'],
    2022: ['2022-04-26', '2022-04-26'],
    2023: ['2023-04-26', '2023-04-26'],
    2024: ['2024-05-14', '2024-05-14'],
    2025: ['2025-04-22', '2025-04-22']
}

# Holodomor Memorial Day - fourth Saturday in November
holodomor_memorial_windows = {
    2015: ['2015-11-28', '2015-11-28'],
    2016: ['2016-11-26', '2016-11-26'],
    2017: ['2017-11-25', '2017-11-25'],
    2018: ['2018-11-24', '2018-11-24'],
    2019: ['2019-11-23', '2019-11-23'],
    2020: ['2020-11-28', '2020-11-28'],
    2021: ['2021-11-27', '2021-11-27'],
    2022: ['2022-11-26', '2022-11-26'],
    2023: ['2023-11-25', '2023-11-25'],
    2024: ['2024-11-23', '2024-11-23'],
    2025: ['2025-11-22', '2025-11-22']
}
# Combine into a dictionary for easy looping
manual_windows = {
    "Jerusalem Day": jerusalem_day_windows,
    "Yom HaShoah": yom_hashoah_windows,
    "Memorial Day": memorial_day_windows, 
    "Independence Day (Israel)": independence_day_windows,
    "Holodomor Memorial Day" : holodomor_memorial_windows

}




for article, window_dict in manual_windows.items():
    mask = df_filtered["article"] == article
    df_filtered.loc[mask, "event_windows"] = [window_dict] * mask.sum()


print(df_filtered)
# Out:
#                                               article  \
# 0                   Armenian Genocide Remembrance Day
# 1                                    Black Ribbon Day
# 2                          Circassian Day of Mourning
# 3               Genocide Remembrance Day (Bangladesh)
# 4                              Holodomor Memorial Day
# 5   International Day of Reflection on the 1994 Rw...
# 6                          Martyred Intellectuals Day
# 7           National Day for Truth and Reconciliation
# 8              National Day of Remembrance (Cambodia)
# 9                                  National Sorry Day
# 10                                  White Armband Day
#
#                      event_date  \
# 0                      April 24
# 1                     August 23
# 2                        May 21
# 3                      March 25
# 4   fourth Saturday in November
# 5                       April 7
# 6                   December 14
# 7                  September 30
# 8                        May 20
# 9                        May 26
# 10                       May 31
#
#                                         event_windows
# 0   {2015: ['2015-04-21', '2015-04-27'], 2016: ['2...
# 1   {2015: ['2015-08-20', '2015-08-26'], 2016: ['2...
# 2   {2015: ['2015-05-18', '2015-05-24'], 2016: ['2...
# 3   {2015: ['2015-03-22', '2015-03-28'], 2016: ['2...
# 4   {2015: ['2015-11-28', '2015-11-28'], 2016: ['2...
# 5   {2015: ['2015-04-04', '2015-04-10'], 2016: ['2...
# 6   {2015: ['2015-12-11', '2015-12-17'], 2016: ['2...
# 7   {2015: ['2015-09-27', '2015-10-03'], 2016: ['2...
# 8   {2015: ['2015-05-17', '2015-05-23'], 2016: ['2...
# 9   {2015: ['2015-05-23', '2015-05-29'], 2016: ['2...
# 10  {2015: ['2015-05-28', '2015-06-03'], 2016: ['2...

# %%
df_meta
# Out:
#                                               article  \
# 0                   Armenian Genocide Remembrance Day
# 1                                    Black Ribbon Day
# 2                          Circassian Day of Mourning
# 3               Genocide Remembrance Day (Bangladesh)
# 4                              Holodomor Memorial Day
# 5   International Day of Reflection on the 1994 Rw...
# 6                          Martyred Intellectuals Day
# 7           National Day for Truth and Reconciliation
# 8              National Day of Remembrance (Cambodia)
# 9                                  National Sorry Day
# 10                                  White Armband Day
#
#                      event_date  \
# 0                      April 24
# 1                     August 23
# 2                        May 21
# 3                      March 25
# 4   fourth Saturday in November
# 5                       April 7
# 6                   December 14
# 7                  September 30
# 8                        May 20
# 9                        May 26
# 10                       May 31
#
#                                         event_windows
# 0   {2015: ['2015-04-21', '2015-04-27'], 2016: ['2...
# 1   {2015: ['2015-08-20', '2015-08-26'], 2016: ['2...
# 2   {2015: ['2015-05-18', '2015-05-24'], 2016: ['2...
# 3   {2015: ['2015-03-22', '2015-03-28'], 2016: ['2...
# 4   {2015: ['2015-11-28', '2015-11-28'], 2016: ['2...
# 5   {2015: ['2015-04-04', '2015-04-10'], 2016: ['2...
# 6   {2015: ['2015-12-11', '2015-12-17'], 2016: ['2...
# 7   {2015: ['2015-09-27', '2015-10-03'], 2016: ['2...
# 8   {2015: ['2015-05-17', '2015-05-23'], 2016: ['2...
# 9   {2015: ['2015-05-23', '2015-05-29'], 2016: ['2...
# 10  {2015: ['2015-05-28', '2015-06-03'], 2016: ['2...

# %%
df_filtered.to_csv("newnew_try.csv", index = False)

# %% [markdown]
# Pairing Source and Target Articles with event window

# %%
# Prepare articles with all needed columns
articles = df_filtered[[
    "article", "event_windows", "subcategories", "categories", "links"
]].drop_duplicates(subset="article")

# Build all source-target pairs (excluding self-pairs)
pairs = pd.DataFrame([
    (src, tgt)
    for src in articles["article"]
    for tgt in articles["article"]
    if src != tgt
], columns=["source", "target"])

# Merge source info
pairs = pairs.merge(
    articles.rename(columns={
        "article": "source",
        "event_windows": "source_window",
        "subcategories": "source_subcategory",
        "categories": "source_category",
        "links": "source_links"
    }),
    on="source",
    how="left"
)

# Merge target info
pairs = pairs.merge(
    articles.rename(columns={
        "article": "target",
        "event_windows": "target_window",
        "subcategories": "target_subcategory",
        "categories": "target_category",
        "links": "target_links"
    }),
    on="target",
    how="left"
)

print(pairs.head())
# Out:
#           source                      target  \
# 0  Cinco de Mayo  Freedom Day (South Africa)
# 1  Cinco de Mayo               Jerusalem Day
# 2  Cinco de Mayo                   Nakba Day
# 3  Cinco de Mayo        National Women's Day
# 4  Cinco de Mayo       Republic Day (Turkey)
#
#                                        source_window  \
# 0  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 1  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 2  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 3  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 4  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
#
#                                   source_subcategory  \
# 0  ['Category:Short description is different from...
# 1  ['Category:Short description is different from...
# 2  ['Category:Short description is different from...
# 3  ['Category:Short description is different from...
# 4  ['Category:Short description is different from...
#
#                                      source_category  \
# 0  ['Category:1862 establishments in Mexico', 'Ca...
# 1  ['Category:1862 establishments in Mexico', 'Ca...
# 2  ['Category:1862 establishments in Mexico', 'Ca...
# 3  ['Category:1862 establishments in Mexico', 'Ca...
# 4  ['Category:1862 establishments in Mexico', 'Ca...
#
#                                         source_links  \
# 0  [420 (cannabis culture), Abbotsford, British C...
# 1  [420 (cannabis culture), Abbotsford, British C...
# 2  [420 (cannabis culture), Abbotsford, British C...
# 3  [420 (cannabis culture), Abbotsford, British C...
# 4  [420 (cannabis culture), Abbotsford, British C...
#
#                                        target_window  \
# 0  {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 1  {2015: ['2015-05-21', '2015-05-21'], 2016: ['2...
# 2  {2015: ['2015-05-12', '2015-05-18'], 2016: ['2...
# 3  {2015: ['2015-08-06', '2015-08-12'], 2016: ['2...
# 4  {2015: ['2015-10-25', '2015-10-31'], 2016: ['2...
#
#                                   target_subcategory  \
# 0  ['Category:South African companies established...
# 1  ['Category:Israeli companies established in 19...
# 2  ['Category:Articles containing Algerian Arabic...
# 3  ['Category:Short description is different from...
# 4  ['Category:Short description is different from...
#
#                                      target_category  \
# 0  ['Category:1994 establishments in South Africa...
# 1  ['Category:1968 establishments in Israel', 'Ca...
# 2  ['Category:Articles containing Arabic-language...
# 3  ['Category:All Wikipedia articles written in S...
# 4  ['Category:All articles with unsourced stateme...
#
#                                         target_links
# 0  [1994 South African general election, Aparthei...
# 1  [1947–1948 civil war in Mandatory Palestine, 1...
# 2  ['Ajjur, 'Akbara, 1947–1948 civil war in Manda...
# 3  [Afrikaans language, Apartheid era, Boxing Day...
# 4  [100th Anniversary of the Republic of Turkey, ...

# %%
def days_between_windows(source_window, target_window, year):
    """Compute min difference in days between two windows for a given year."""
    s_start = datetime.strptime(source_window[year][0], "%Y-%m-%d")
    s_end = datetime.strptime(source_window[year][1], "%Y-%m-%d")
    t_start = datetime.strptime(target_window[year][0], "%Y-%m-%d")
    t_end = datetime.strptime(target_window[year][1], "%Y-%m-%d")
    
    # All possible combinations of start/end dates
    diffs = [
        abs((s_start - t_start).days),
        abs((s_start - t_end).days),
        abs((s_end - t_start).days),
        abs((s_end - t_end).days)
    ]
    return min(diffs)

def min_days_between_all_years(source_window, target_window):
    years = set(source_window.keys()) & set(target_window.keys())
    min_diff = float('inf')
    for y in years:
        diff = days_between_windows(source_window, target_window, y)
        if diff < min_diff:
            min_diff = diff
    return min_diff

pairs["min_day_diff"] = pairs.apply(
    lambda row: min_days_between_all_years(row["source_window"], row["target_window"]),
    axis=1
)

pairs_filtered = pairs[pairs["min_day_diff"] > 10]

# %%
pairs_filtered
# Out:
#                      source                                          target  \
# 3             Cinco de Mayo                            National Women's Day
# 4             Cinco de Mayo                           Republic Day (Turkey)
# 5             Cinco de Mayo                                    Waitangi Day
# 6             Cinco de Mayo  National Day of the People's Republic of China
# 7             Cinco de Mayo           National Day of the Republic of China
# ...                     ...                                             ...
# 2062  Victory in Europe Day                                 Great Union Day
# 2063  Victory in Europe Day                              Unity Day (Russia)
# 2065  Victory in Europe Day                                    Veterans Day
# 2066  Victory in Europe Day                              Kargil Vijay Diwas
# 2067  Victory in Europe Day                          Victory over Japan Day
#
#                                           source_window  \
# 3     {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 4     {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 5     {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 6     {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 7     {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...                                                 ...
# 2062  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 2063  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 2065  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 2066  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 2067  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
#                                      source_subcategory  \
# 3     ['Category:Short description is different from...
# 4     ['Category:Short description is different from...
# 5     ['Category:Short description is different from...
# 6     ['Category:Short description is different from...
# 7     ['Category:Short description is different from...
# ...                                                 ...
# 2062  ['Category:1945 crimes in Europe', 'Category:1...
# 2063  ['Category:1945 crimes in Europe', 'Category:1...
# 2065  ['Category:1945 crimes in Europe', 'Category:1...
# 2066  ['Category:1945 crimes in Europe', 'Category:1...
# 2067  ['Category:1945 crimes in Europe', 'Category:1...
#
#                                         source_category  \
# 3     ['Category:1862 establishments in Mexico', 'Ca...
# 4     ['Category:1862 establishments in Mexico', 'Ca...
# 5     ['Category:1862 establishments in Mexico', 'Ca...
# 6     ['Category:1862 establishments in Mexico', 'Ca...
# 7     ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                 ...
# 2062  ['Category:1945 in Europe', 'Category:All arti...
# 2063  ['Category:1945 in Europe', 'Category:All arti...
# 2065  ['Category:1945 in Europe', 'Category:All arti...
# 2066  ['Category:1945 in Europe', 'Category:All arti...
# 2067  ['Category:1945 in Europe', 'Category:All arti...
#
#                                            source_links  \
# 3     [420 (cannabis culture), Abbotsford, British C...
# 4     [420 (cannabis culture), Abbotsford, British C...
# 5     [420 (cannabis culture), Abbotsford, British C...
# 6     [420 (cannabis culture), Abbotsford, British C...
# 7     [420 (cannabis culture), Abbotsford, British C...
# ...                                                 ...
# 2062  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 2063  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 2065  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 2066  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 2067  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
#
#                                           target_window  \
# 3     {2015: ['2015-08-06', '2015-08-12'], 2016: ['2...
# 4     {2015: ['2015-10-25', '2015-10-31'], 2016: ['2...
# 5     {2015: ['2015-02-03', '2015-02-09'], 2016: ['2...
# 6     {2015: ['2015-09-28', '2015-10-04'], 2016: ['2...
# 7     {2015: ['2015-10-07', '2015-10-13'], 2016: ['2...
# ...                                                 ...
# 2062  {2015: ['2015-11-28', '2015-12-04'], 2016: ['2...
# 2063  {2015: ['2015-11-01', '2015-11-07'], 2016: ['2...
# 2065  {2015: ['2015-11-08', '2015-11-14'], 2016: ['2...
# 2066  {2015: ['2015-07-23', '2015-07-29'], 2016: ['2...
# 2067  {2015: ['2015-08-12', '2015-08-18'], 2016: ['2...
#
#                                      target_subcategory  \
# 3     ['Category:Short description is different from...
# 4     ['Category:Short description is different from...
# 5     ['Category:New Zealand companies established i...
# 6     ['Category:Articles containing simplified Chin...
# 7     ['Category:People of the 1911 Revolution', 'Ca...
# ...                                                 ...
# 2062  ['Category:Railway stations in Romania opened ...
# 2063  ['Category:Short description is different from...
# 2065  ['Category:1919 establishments in Alabama', 'C...
# 2066  ['Category:Annual sporting events in India', '...
# 2067  ['Category:1945 crimes in Asia', 'Category:194...
#
#                                         target_category  \
# 3     ['Category:All Wikipedia articles written in S...
# 4     ['Category:All articles with unsourced stateme...
# 5     ['Category:1934 establishments in New Zealand'...
# 6     ['Category:Articles containing Chinese-languag...
# 7     ['Category:1911 Revolution', 'Category:All art...
# ...                                                 ...
# 2062  ['Category:1990 establishments in Romania', 'C...
# 2063  ['Category:Articles containing Russian-languag...
# 2065  ['Category:1919 establishments in the United S...
# 2066  ['Category:All Wikipedia articles written in I...
# 2067  ['Category:1945 in Asia', 'Category:1945 in Ja...
#
#                                            target_links  min_day_diff
# 3     [Afrikaans language, Apartheid era, Boxing Day...            90
# 4     [100th Anniversary of the Republic of Turkey, ...           170
# 5     [Air New Zealand, Anzac Day, Araucaria araucan...            82
# 6     [100th Anniversary of the Chinese Communist Pa...           143
# 7     [100th Anniversary of the Republic of China, 1...           152
# ...                                                 ...           ...
# 2062  [1918 Romanian National Assembly election, 194...           201
# 2063  [1612 (film), Christmas in Russia, Communist P...           174
# 2065  [420 (cannabis culture), Advent Sunday, Alabam...           181
# 2066  [Allahabad, Amar Jawan Jyoti, ISBN (identifier...            73
# 2067  [1945 Harbin Victory Day Parade, 2015 China Vi...            93
#
# [1818 rows x 11 columns]

# %%
def get_total_pageviews(start, end):
    url = (
        f"https://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/"
        f"en.wikipedia/all-access/all-agents/daily/{start}/{end}"
    )
    headers = {"User-Agent": "MyResearchBot/1.0 (your_email@example.com)"}
    r = requests.get(url, headers=headers)
    data = r.json()
    views = [
        {"date": item["timestamp"][:8], "total_views": item["views"]}
        for item in data["items"]
    ]
    df = pd.DataFrame(views)
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")
    return df

# %%
# get total Wikipedia traffic for the same period
total_df = get_total_pageviews("20150701", "20250109")

# %%
# Convert df_filtered['date'] to datetime
df_filtered['date'] = pd.to_datetime(df_filtered['date'])

# Make sure total_df also has datetime
total_df['date'] = pd.to_datetime(total_df['date'])
# Out:
# C:\Users\daihe\AppData\Local\Temp\ipykernel_7296\2643698031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['date'] = pd.to_datetime(df_filtered['date'])

# %%
df_filtered
# Out:
#         Unnamed: 0                article         creation_date  \
# 10421        10421          Cinco de Mayo  2001-07-24T05:20:12Z
# 10422        10422          Cinco de Mayo  2001-07-24T05:20:12Z
# 10423        10423          Cinco de Mayo  2001-07-24T05:20:12Z
# 10424        10424          Cinco de Mayo  2001-07-24T05:20:12Z
# 10425        10425          Cinco de Mayo  2001-07-24T05:20:12Z
# ...            ...                    ...                   ...
# 781117      781117  Victory in Europe Day  2003-04-24T03:52:57Z
# 781118      781118  Victory in Europe Day  2003-04-24T03:52:57Z
# 781119      781119  Victory in Europe Day  2003-04-24T03:52:57Z
# 781120      781120  Victory in Europe Day  2003-04-24T03:52:57Z
# 781121      781121  Victory in Europe Day  2003-04-24T03:52:57Z
#
#                                                categories  \
# 10421   ['Category:1862 establishments in Mexico', 'Ca...
# 10422   ['Category:1862 establishments in Mexico', 'Ca...
# 10423   ['Category:1862 establishments in Mexico', 'Ca...
# 10424   ['Category:1862 establishments in Mexico', 'Ca...
# 10425   ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                   ...
# 781117  ['Category:1945 in Europe', 'Category:All arti...
# 781118  ['Category:1945 in Europe', 'Category:All arti...
# 781119  ['Category:1945 in Europe', 'Category:All arti...
# 781120  ['Category:1945 in Europe', 'Category:All arti...
# 781121  ['Category:1945 in Europe', 'Category:All arti...
#
#                                             subcategories event_date country  \
# 10421   ['Category:Short description is different from...      May 5  Mexico
# 10422   ['Category:Short description is different from...      May 5  Mexico
# 10423   ['Category:Short description is different from...      May 5  Mexico
# 10424   ['Category:Short description is different from...      May 5  Mexico
# 10425   ['Category:Short description is different from...      May 5  Mexico
# ...                                                   ...        ...     ...
# 781117  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781118  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781119  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781120  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
# 781121  ['Category:1945 crimes in Europe', 'Category:1...      May 8  France
#
#             continent                                      event_windows  \
# 10421   North America  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 10422   North America  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 10423   North America  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 10424   North America  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 10425   North America  {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...               ...                                                ...
# 781117         Europe  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 781118         Europe  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 781119         Europe  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 781120         Europe  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 781121         Europe  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
#              date   views    pageid  \
# 10421  2015-07-01  2278.0  26482586
# 10422  2015-07-02  3179.0  26482586
# 10423  2015-07-03  3860.0  26482586
# 10424  2015-07-04  6243.0  26482586
# 10425  2015-07-05  4723.0  26482586
# ...           ...     ...       ...
# 781117 2025-01-03  1067.0    215257
# 781118 2025-01-04  1077.0    215257
# 781119 2025-01-05  1225.0    215257
# 781120 2025-01-06  1115.0    215257
# 781121 2025-01-07  1057.0    215257
#
#                                                     links  is_event_window
# 10421   ['420 (cannabis culture)', 'Abbotsford, Britis...            False
# 10422   ['420 (cannabis culture)', 'Abbotsford, Britis...            False
# 10423   ['420 (cannabis culture)', 'Abbotsford, Britis...            False
# 10424   ['420 (cannabis culture)', 'Abbotsford, Britis...            False
# 10425   ['420 (cannabis culture)', 'Abbotsford, Britis...            False
# ...                                                   ...              ...
# 781117  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781118  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781119  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781120  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
# 781121  ['1985 Warsaw Victory Day Parade', '2005 Mosco...            False
#
# [151353 rows x 14 columns]

# %%
# merge on date
df_filtered = df_filtered.merge(total_df, on="date", how="left")

# normalize
df_filtered["normalized_views"] = df_filtered["views"] / df_filtered["total_views"]

# %%
df_filtered["date"] = pd.to_datetime(df_filtered["date"])

# Extract year
df_filtered["year"] = df_filtered["date"].dt.year

# %%
#target_views = df_filtered[['article', 'views', 'date', 'normalized_views', 'baseline_norm']]
target_views = df_filtered[['article', 'views', 'date', 'normalized_views', ]]

# %%
target_views = target_views.rename(columns = {"article" : "target"})

# %%
#pairs_df_new = pairs_filtered.merge(
    target_views[['target', 'views', 'date', 'normalized_views', 'baseline_norm']],
    on='target',
    how='left'
)

# %%
pairs_df_new = pairs.merge(
    target_views,
    on="target",
    how="left"
)

# %%
pairs_df_new = pairs_df_new.rename(columns = {"event_windows" : "source_event_windows" })

# %%
pairs_df_new = pd.read_csv("complete_pairs_df.csv")

# %%
pairs_df_new = pd.read_csv("complete_pairs_df.csv")

# %%
pairs_df_new
# Out:
#                         source                      target  \
# 0                Cinco de Mayo  Freedom Day (South Africa)
# 1                Cinco de Mayo  Freedom Day (South Africa)
# 2                Cinco de Mayo  Freedom Day (South Africa)
# 3                Cinco de Mayo  Freedom Day (South Africa)
# 4                Cinco de Mayo  Freedom Day (South Africa)
# ...                        ...                         ...
# 6808225  Victory in Europe Day         Victory Day (9 May)
# 6808226  Victory in Europe Day         Victory Day (9 May)
# 6808227  Victory in Europe Day         Victory Day (9 May)
# 6808228  Victory in Europe Day         Victory Day (9 May)
# 6808229  Victory in Europe Day         Victory Day (9 May)
#
#                                              source_window  \
# 0        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 1        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 2        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 3        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 4        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...                                                    ...
# 6808225  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808226  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808227  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808228  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808229  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
#                                         source_subcategory  \
# 0        ['Category:Short description is different from...
# 1        ['Category:Short description is different from...
# 2        ['Category:Short description is different from...
# 3        ['Category:Short description is different from...
# 4        ['Category:Short description is different from...
# ...                                                    ...
# 6808225  ['Category:1945 crimes in Europe', 'Category:1...
# 6808226  ['Category:1945 crimes in Europe', 'Category:1...
# 6808227  ['Category:1945 crimes in Europe', 'Category:1...
# 6808228  ['Category:1945 crimes in Europe', 'Category:1...
# 6808229  ['Category:1945 crimes in Europe', 'Category:1...
#
#                                            source_category  \
# 0        ['Category:1862 establishments in Mexico', 'Ca...
# 1        ['Category:1862 establishments in Mexico', 'Ca...
# 2        ['Category:1862 establishments in Mexico', 'Ca...
# 3        ['Category:1862 establishments in Mexico', 'Ca...
# 4        ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                    ...
# 6808225  ['Category:1945 in Europe', 'Category:All arti...
# 6808226  ['Category:1945 in Europe', 'Category:All arti...
# 6808227  ['Category:1945 in Europe', 'Category:All arti...
# 6808228  ['Category:1945 in Europe', 'Category:All arti...
# 6808229  ['Category:1945 in Europe', 'Category:All arti...
#
#                                               source_links  \
# 0        [420 (cannabis culture), Abbotsford, British C...
# 1        [420 (cannabis culture), Abbotsford, British C...
# 2        [420 (cannabis culture), Abbotsford, British C...
# 3        [420 (cannabis culture), Abbotsford, British C...
# 4        [420 (cannabis culture), Abbotsford, British C...
# ...                                                    ...
# 6808225  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808226  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808227  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808228  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808229  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
#
#                                              target_window  \
# 0        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 1        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 2        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 3        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 4        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# ...                                                    ...
# 6808225  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808226  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808227  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808228  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808229  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
#
#                                         target_subcategory  \
# 0        ['Category:South African companies established...
# 1        ['Category:South African companies established...
# 2        ['Category:South African companies established...
# 3        ['Category:South African companies established...
# 4        ['Category:South African companies established...
# ...                                                    ...
# 6808225  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808226  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808227  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808228  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808229  ['Category:Amerika Häuser', 'Category:Ethnic c...
#
#                                            target_category  \
# 0        ['Category:1994 establishments in South Africa...
# 1        ['Category:1994 establishments in South Africa...
# 2        ['Category:1994 establishments in South Africa...
# 3        ['Category:1994 establishments in South Africa...
# 4        ['Category:1994 establishments in South Africa...
# ...                                                    ...
# 6808225  ['Category:2015 disestablishments in Ukraine',...
# 6808226  ['Category:2015 disestablishments in Ukraine',...
# 6808227  ['Category:2015 disestablishments in Ukraine',...
# 6808228  ['Category:2015 disestablishments in Ukraine',...
# 6808229  ['Category:2015 disestablishments in Ukraine',...
#
#                                               target_links  min_day_diff  \
# 0        [1994 South African general election, Aparthei...             2
# 1        [1994 South African general election, Aparthei...             2
# 2        [1994 South African general election, Aparthei...             2
# 3        [1994 South African general election, Aparthei...             2
# 4        [1994 South African general election, Aparthei...             2
# ...                                                    ...           ...
# 6808225  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808226  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808227  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808228  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808229  [150th Rifle Division, 154th Preobrazhensky In...             1
#
#          views       date  normalized_views
# 0           77 2016-01-01      2.858294e-07
# 1           46 2016-01-02      1.570376e-07
# 2           39 2016-01-03      1.302175e-07
# 3           48 2016-01-04      1.569148e-07
# 4           48 2016-01-05      1.598415e-07
# ...        ...        ...               ...
# 6808225    477 2024-12-28      1.256349e-06
# 6808226    455 2024-12-29      1.146698e-06
# 6808227    474 2024-12-30      1.205486e-06
# 6808228    450 2024-12-31      1.224486e-06
# 6808229    495 2025-01-01      1.276612e-06
#
# [6808230 rows x 14 columns]

# %%
test_row = pairs_df_new[:10002]

# %%
pairs_df_new
# Out:
#                         source                      target  \
# 0                Cinco de Mayo  Freedom Day (South Africa)
# 1                Cinco de Mayo  Freedom Day (South Africa)
# 2                Cinco de Mayo  Freedom Day (South Africa)
# 3                Cinco de Mayo  Freedom Day (South Africa)
# 4                Cinco de Mayo  Freedom Day (South Africa)
# ...                        ...                         ...
# 6808225  Victory in Europe Day         Victory Day (9 May)
# 6808226  Victory in Europe Day         Victory Day (9 May)
# 6808227  Victory in Europe Day         Victory Day (9 May)
# 6808228  Victory in Europe Day         Victory Day (9 May)
# 6808229  Victory in Europe Day         Victory Day (9 May)
#
#                                              source_window  \
# 0        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 1        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 2        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 3        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# 4        {2015: ['2015-05-02', '2015-05-08'], 2016: ['2...
# ...                                                    ...
# 6808225  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808226  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808227  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808228  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
# 6808229  {2015: ['2015-05-05', '2015-05-11'], 2016: ['2...
#
#                                         source_subcategory  \
# 0        ['Category:Short description is different from...
# 1        ['Category:Short description is different from...
# 2        ['Category:Short description is different from...
# 3        ['Category:Short description is different from...
# 4        ['Category:Short description is different from...
# ...                                                    ...
# 6808225  ['Category:1945 crimes in Europe', 'Category:1...
# 6808226  ['Category:1945 crimes in Europe', 'Category:1...
# 6808227  ['Category:1945 crimes in Europe', 'Category:1...
# 6808228  ['Category:1945 crimes in Europe', 'Category:1...
# 6808229  ['Category:1945 crimes in Europe', 'Category:1...
#
#                                            source_category  \
# 0        ['Category:1862 establishments in Mexico', 'Ca...
# 1        ['Category:1862 establishments in Mexico', 'Ca...
# 2        ['Category:1862 establishments in Mexico', 'Ca...
# 3        ['Category:1862 establishments in Mexico', 'Ca...
# 4        ['Category:1862 establishments in Mexico', 'Ca...
# ...                                                    ...
# 6808225  ['Category:1945 in Europe', 'Category:All arti...
# 6808226  ['Category:1945 in Europe', 'Category:All arti...
# 6808227  ['Category:1945 in Europe', 'Category:All arti...
# 6808228  ['Category:1945 in Europe', 'Category:All arti...
# 6808229  ['Category:1945 in Europe', 'Category:All arti...
#
#                                               source_links  \
# 0        [420 (cannabis culture), Abbotsford, British C...
# 1        [420 (cannabis culture), Abbotsford, British C...
# 2        [420 (cannabis culture), Abbotsford, British C...
# 3        [420 (cannabis culture), Abbotsford, British C...
# 4        [420 (cannabis culture), Abbotsford, British C...
# ...                                                    ...
# 6808225  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808226  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808227  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808228  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
# 6808229  [1985 Warsaw Victory Day Parade, 2005 Moscow V...
#
#                                              target_window  \
# 0        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 1        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 2        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 3        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# 4        {2015: ['2015-04-24', '2015-04-30'], 2016: ['2...
# ...                                                    ...
# 6808225  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808226  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808227  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808228  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
# 6808229  {2015: ['2015-05-06', '2015-05-12'], 2016: ['2...
#
#                                         target_subcategory  \
# 0        ['Category:South African companies established...
# 1        ['Category:South African companies established...
# 2        ['Category:South African companies established...
# 3        ['Category:South African companies established...
# 4        ['Category:South African companies established...
# ...                                                    ...
# 6808225  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808226  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808227  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808228  ['Category:Amerika Häuser', 'Category:Ethnic c...
# 6808229  ['Category:Amerika Häuser', 'Category:Ethnic c...
#
#                                            target_category  \
# 0        ['Category:1994 establishments in South Africa...
# 1        ['Category:1994 establishments in South Africa...
# 2        ['Category:1994 establishments in South Africa...
# 3        ['Category:1994 establishments in South Africa...
# 4        ['Category:1994 establishments in South Africa...
# ...                                                    ...
# 6808225  ['Category:2015 disestablishments in Ukraine',...
# 6808226  ['Category:2015 disestablishments in Ukraine',...
# 6808227  ['Category:2015 disestablishments in Ukraine',...
# 6808228  ['Category:2015 disestablishments in Ukraine',...
# 6808229  ['Category:2015 disestablishments in Ukraine',...
#
#                                               target_links  min_day_diff  \
# 0        [1994 South African general election, Aparthei...             2
# 1        [1994 South African general election, Aparthei...             2
# 2        [1994 South African general election, Aparthei...             2
# 3        [1994 South African general election, Aparthei...             2
# 4        [1994 South African general election, Aparthei...             2
# ...                                                    ...           ...
# 6808225  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808226  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808227  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808228  [150th Rifle Division, 154th Preobrazhensky In...             1
# 6808229  [150th Rifle Division, 154th Preobrazhensky In...             1
#
#          views       date  normalized_views
# 0           77 2016-01-01      2.858294e-07
# 1           46 2016-01-02      1.570376e-07
# 2           39 2016-01-03      1.302175e-07
# 3           48 2016-01-04      1.569148e-07
# 4           48 2016-01-05      1.598415e-07
# ...        ...        ...               ...
# 6808225    477 2024-12-28      1.256349e-06
# 6808226    455 2024-12-29      1.146698e-06
# 6808227    474 2024-12-30      1.205486e-06
# 6808228    450 2024-12-31      1.224486e-06
# 6808229    495 2025-01-01      1.276612e-06
#
# [6808230 rows x 14 columns]

# %%
pairs_df_new["in_source_window"] = window_df.groupby("index")["in_source_window"].any().reindex(pairs_df_new.index, fill_value=False)

# %%
pairs_df_new["in_source_window"].value_counts()
# Out:
# in_source_window
# False    6686320
# True      124565
# Name: count, dtype: int64

# %%
view_flow.to_csv("view_flow_final.csv", index = False)

# %% [markdown]
# filter to event windows only

# %%
view_flow = pd.read_csv("view_flow_final.csv")

# %%
view_flow["source"].unique()
# Out:
# array(['Anzac Day', 'Armistice Day', 'Cinco de Mayo',
#        'Constitution Day (Norway)', 'Festa della Repubblica',
#        'Freedom Day (South Africa)', 'German Unity Day',
#        'Great Union Day', 'Grito de Lares',
#        'Independence Day (Bangladesh)', 'Independence Day (Brazil)',
#        'Independence Day (Finland)', 'Independence Day (India)',
#        'Independence Day (Indonesia)', 'Independence Day (Israel)',
#        'Independence Day (Malaysia)', 'Independence Day (Nigeria)',
#        'Independence Day (Pakistan)', 'Independence Day (Philippines)',
#        'Independence Day (Sri Lanka)', 'Independence Day (United States)',
#        'Independence Day of Ukraine', 'Jerusalem Day', 'Memorial Day',
#        'National Day (Singapore)',
#        'National Day for Truth and Reconciliation',
#        "National Day of the People's Republic of China",
#        'National Day of the Republic of China',
#        'National Foundation Day (Japan)',
#        'National Independence Day (Poland)',
#        'National Liberation Day of Korea', 'National Sorry Day',
#        "National Women's Day", 'Remembrance Day', 'Remembrance Sunday',
#        'Republic Day (India)', 'Republic Day (Turkey)',
#        'Reunification Day', 'Unity Day (Russia)', 'Veterans Day',
#        'Victory Day (9 May)', 'Victory Day (Bangladesh)',
#        'Victory in Europe Day', 'Victory over Japan Day', 'Waitangi Day',
#        'Yom HaShoah'], dtype=object)

# %%
in_source_window_true = pairs_df_new.loc[pairs_df_new.in_source_window]

# %%
pairs_df_new["year"] = pd.to_datetime(pairs_df_new["date"]).dt.year

# %% [markdown]
# Flag whether each row is inside the source event window

# %%
def in_window(row, window_col):
    year = row["year"]
    window = row[window_col]
    if pd.isna(window) or not isinstance(window, dict) or year not in window:
        return False
    start, end = pd.to_datetime(window[year])
    return start <= row["date"] <= end

pairs_df_new["in_source_window"] = pairs_df_new.apply(
    lambda row: in_window(row, "source_window"), axis=1
)

# %% [markdown]
# Compute the baseline

# %%
baseline = (
    pairs_df_new[~pairs_df_new["in_source_window"]]
    .groupby(["target", "year"])["normalized_views"]
    .mean()
    .reset_index()
    .rename(columns={"normalized_views": "baseline_norm"})
)

# %% [markdown]
# Attach baseline back to the datafram

# %%
pairs_df_new = pairs_df_new.merge(baseline, on=["target", "year"], how="left")

# %%
view_flow = (
    pairs_df_new[pairs_df_new["in_source_window"]]
    .groupby(["source", "target", "year"])
    .agg(
        observed_views=("normalized_views", "sum"),
        baseline_mean=("baseline_norm", "first"),  # daily baseline
        window_days=("normalized_views", "count")
    )
    .reset_index()
)

view_flow["baseline_total"] = view_flow["baseline_mean"] * view_flow["window_days"]
view_flow["view_flow"] = view_flow["observed_views"] - view_flow["baseline_total"]
